# %% [markdown]
# <a href="https://colab.research.google.com/github/Yazmin-Nopal/MapaQgis/blob/main/laboratorio01/ada_p01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook de Autoestudio: Introducción a Python

# %% [markdown]
# <div style="text-align: center;">
# <p><strong>Análisis de Algoritmos, 2026-2</strong></p>
# <p>Manuel Soto Romero</p>
# <p>12 de febrero de 2026</p>
# <p>Colegio de Ciencia y Tecnología, UACM</p>
# </div>

# %% [markdown]
# ---
# ## Cómo usar este notebook
# ---

# %% [markdown]
# Este notebook es de autoestudio. Cada tema incluye:
# - Una explicación breve.
# - Una celda con **código de ejemplo** para ejecutar.
# - Un **ejercicio corto** con una celda para completar.
#
# Sigue este orden en cada tema: lee, ejecuta el ejemplo, resuelve el ejercicio.

# %% [markdown]
# ## Tema 1. Sintaxis básica
# Python usa indentación para definir bloques. Las variables se crean con `=` y se puede imprimir con `print`.

# %%
# Ejemplo: variables, operaciones y print
a = 5
b = 3

suma = a + b
producto = a * b

print('Suma:', suma)
print('Producto:', producto)

# %%
# Ejercicio: completa el código
# Calcula el área de un rectángulo (base * altura)

base = 0
altura = 0

area = 0

print('Área:', area)

# %% [markdown]
# ## Tema 2. Tipos de datos básicos
# Los tipos más usados son: `int` (enteros), `float` (decimales), `str` (texto) y `bool` (verdadero/falso).

# %%
# Ejemplo: tipos y type()
entero = 10
flotante = 3.14
texto = 'Hola'
bandera = True

print(type(entero))
print(type(flotante))
print(type(texto))
print(type(bandera))

# %%
# Ejercicio: crea una variable de cada tipo y muestra su tipo
entero = 0
flotante = 0.0
texto = ''
bandera = False

print(type(entero))
print(type(flotante))
print(type(texto))
print(type(bandera))

# %% [markdown]
# ## Tema 3. Listas
# Una lista guarda varios valores en orden. Se crea con `[]`, se accede con índices y se puede recorrer con `for`.

# %%
# Ejemplo: listas, índices y append
numeros = [1, 2, 3]
print('Primero:', numeros[0])
print('Último:', numeros[-1])

numeros.append(4)
print('Lista:', numeros)

# %%
# Ejercicio: calcula suma y promedio de una lista
numeros = [5, 10, 15, 20]

suma = 0
# Recorre la lista para sumar

promedio = 0

print('Suma:', suma)
print('Promedio:', promedio)

# %% [markdown]
# ## Tema 4. Estructuras de decisión y repetición
# Las decisiones se hacen con `if`, `elif`, `else`. Para repetir acciones se usa `for` con una lista o `range`.

# %%
# Ejemplo: decisión + repetición
valores = [3, -1, 0, 7]

for v in valores:
    if v > 0:
        print(v, 'es positivo')
    elif v < 0:
        print(v, 'es negativo')
    else:
        print(v, 'es cero')

# %%
# Ejercicio: cuenta cuántos positivos hay en la lista
valores = [2, -3, 5, 0, 1, -2]

positivos = 0

for v in valores:
    # Si v es positivo, incrementa positivos
    pass

print('Positivos:', positivos)

# %% [markdown]
# ## Tema 5. Definición de funciones
# Una función permite reutilizar código. Se define con `def` y puede regresar un valor con `return`.

# %%
# Ejemplo: función de conversión
def celsius_a_fahrenheit(c):
    return c * 9/5 + 32

print(celsius_a_fahrenheit(0))
print(celsius_a_fahrenheit(25))

# %%
# Ejercicio: crea una función que regrese el cuadrado de un número
def cuadrado(x):
    # completa la función
    return 0

print(cuadrado(3))
print(cuadrado(10))

# %% [markdown]
# ---
# ## Ejercicios finales: Definición de funciones

# %% [markdown]
# ### Ejercicio F1. Suma de dos números
# Define la función `sumar(a, b)` que regrese la suma de `a` y `b`.

# %%
# TODO: completa la función
def sumar(a, b):
  suma = a+b
  return suma

print(sumar(2, 3))
print(sumar(-1, 5))

# %% [markdown]
# ### Ejercicio F2. Máximo de una lista
# Define la función `maximo(lista)` que regrese el valor mayor de la lista.
# Asume que la lista tiene al menos un elemento.

# %%
# TODO: completa la función
def maximo(lista):
    return 0

print(maximo([3, 7, 2, 9]))
print(maximo([-5, -2, -10]))

# %% [markdown]
# ### Ejercicio F3. Contar pares
# Define la función `contar_pares(lista)` que regrese cuántos números pares hay en la lista.

# %%
# TODO: completa la función
def contar_pares(lista):
    return 0

print(contar_pares([1, 2, 3, 4, 5, 6]))
print(contar_pares([7, 9, 11]))
